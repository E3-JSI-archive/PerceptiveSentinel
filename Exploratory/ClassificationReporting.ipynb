# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# Import auxiliary image maipulation libraries
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np

# Main pipeline class
from CloudSaturation import CloudSaturation

# Image plotting utils
from Utils import *
from MLUtils import *
import datetime
# Out:
# /Users/joosko/work/ijs/ml/SentinelHub/venv/lib/python3.6/site-packages/tifffile/tifffile.py:7685: UserWarning: No module named 'tifffile._tifffile'
#   Functionality might be degraded or be slow.
#
#   warnings.warn('%s%s' % (e, warn))

# %%
# Define bounding box of interest (Tulips field in netherlands in our case)
full_tulip_box = (52.85905593845727, 4.71038818359375, 52.91204098150524, 4.798278808593751)
# Initialize main pipeline object
# This object will hold all auxiliary data structures and methods needed for processing
# most importantly, all calls made for same CloudSaturation object could reuse same cloud detection data, 
# precomputed and stored in self.memo_data for downloaded data
netherlands_cloud = CloudSaturation(full_tulip_box, cloud_scale=2)

# %%
# Acquire first batch of data and cloud filter for corresponding space (determined by bounding box) 
# and time range (determined by constructor parameters)
mask_full, true_c_full, bands, dates_full, cloud_masks_full = \
    netherlands_cloud.get_cloud_saturation_mask()
# Out:
# Saved True color
# Saved cloud detection bands
# Saved bands
# Downloaded data
# Detecting clouds, this may take some time...
# Cloud detection finished

# %%
field_2016, mask_2016, nonzero_2016 = netherlands_cloud.get_tulip_mask("tulip_field_2016")
field_2017, mask_2017, nonzero_2017 = netherlands_cloud.get_tulip_mask("tulip_field_2017")
field_arra, mask_arra, nonzero_arra = netherlands_cloud.get_tulip_mask("arable_land_2017")
print(mask_2016.shape)
# Out:
# Downloaded from http://service.geopedia.world/wms/ml_aws?service=WMS&request=GetMap&styles=&format=image%2Fpng&transparent=false&version=1.1.1&layers=ttl1904&height=589&width=590&srs=EPSG:3857&bbox=524358.0140363087,6956969.518615424,534141.9536568124,6966744.426812871
# Downloaded from http://service.geopedia.world/wms/ml_aws?service=WMS&request=GetMap&styles=&format=image%2Fpng&transparent=false&version=1.1.1&layers=ttl1905&height=589&width=590&srs=EPSG:3857&bbox=524358.0140363087,6956969.518615424,534141.9536568124,6966744.426812871
# Downloaded from http://service.geopedia.world/wms/ml_aws?service=WMS&request=GetMap&styles=&format=image%2Fpng&transparent=false&version=1.1.1&layers=ttl1917&height=589&width=590&srs=EPSG:3857&bbox=524358.0140363087,6956969.518615424,534141.9536568124,6966744.426812871
# (589, 590)

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
test_date = datetime.datetime(year=2016, month=5, day=11)
test_date_index = find_index_after_date(dates_full, test_date)
overlay_cloud_mask(true_c_full[test_date_index], mask_2016)

# %%
iteration_num = 0
def evaluate(model, X_testing, Y_testing):
    predictions = model.predict(X_testing)
    precission = precision_score(Y_testing, predictions)
    recall = recall_score(Y_testing, predictions)
    f1 = f1_score(Y_testing, predictions)
    
    predictions_test = model.predict(X_test)
    precission_t = precision_score(Y_test, predictions_test)
    recall_t = recall_score(Y_test, predictions_test)
    f1_t = f1_score(Y_test, predictions_test)
    
    global iteration_num
    print(f"Iteration: \t\t{iteration_num} \t\tTest data:")
    iteration_num += 1 
    print(f"F1: \t\t\t{f1:.5f}\t\t{f1_t:5f}")
    print(f"Precission: \t\t{precission:.5f}\t\t{precission_t:5f}")
    print(f"Recall: \t\t{recall:.5f}\t\t{recall_t:5f}")
    return f1

# Initial param grid
param_grid = {
    "bootstrap": [True],
    "max_depth": [80, 90, 100, 110],
    "max_features": ["sqrt", "log2"],
    "min_samples_leaf": [3, 4, 5],
    "min_samples_split": [8, 10, 12],
    "n_estimators": [100, 200, 300]
}

test_image_bands = bands[test_date_index]
reshaper = Reshaper(test_image.shape)

X_flat = reshaper.flatten_data(test_image_bands)
Y_flat = reshaper.flatten_labels(mask_2016)

X_train, X_test, Y_train, Y_test = train_test_split(X_flat, Y_flat, train_size=0.5, shuffle=False)

random_forest = RandomForestClassifier()
grid_search = GridSearchCV(estimator=random_forest, param_grid=param_grid, 
                          cv=3, n_jobs=-1, verbose=2, scoring=evaluate)
grid_search.fit(X_flat, Y_flat)
# Out:
# /Users/joosko/work/ijs/ml/SentinelHub/venv/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=100
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=100
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=100
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=200
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=200
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=200
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=300
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=300
# Iteration: 		0 		Test data:
# F1: 			0.81760		0.968866
# Precission: 		0.93503		0.996547
# Recall: 		0.72638		0.942681
# Iteration: 		0 		Test data:
# F1: 			0.78700		0.903796
# Precission: 		0.90600		0.975335
# Recall: 		0.69563		0.842034
# Iteration: 		0 		Test data:
# F1: 			0.72708		0.825689
# Precission: 		0.79999		0.883502
# Recall: 		0.66635		0.774977
# Iteration: 		1 		Test data:
# F1: 			0.96757		0.968866
# Precission: 		0.99633		0.996547
# Recall: 		0.94042		0.942681
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=300
# Iteration: 		1 		Test data:
# F1: 			0.96875		0.903796
# Precission: 		0.99751		0.975335
# Recall: 		0.94161		0.842034
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100
# Iteration: 		1 		Test data:
# F1: 			0.96972		0.825689
# Precission: 		0.99746		0.883502
# Recall: 		0.94348		0.774977
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100
# Iteration: 		0 		Test data:
# F1: 			0.78740		0.904330
# Precission: 		0.90535		0.975463
# Recall: 		0.69664		0.842866
# Iteration: 		0 		Test data:
# F1: 			0.81811		0.969492
# Precission: 		0.93660		0.996907
# Recall: 		0.72623		0.943544
# Iteration: 		0 		Test data:
# F1: 			0.72732		0.826147
# Precission: 		0.79978		0.883430
# Recall: 		0.66690		0.775840
# Iteration: 		2 		Test data:
# F1: 			0.81876		0.962036
# Precission: 		0.93790		0.994930
# Recall: 		0.72648		0.931248
# Iteration: 		2 		Test data:
# F1: 			0.78743		0.898985
# Precission: 		0.90381		0.973830
# Recall: 		0.69760		0.834823
# Iteration: 		1 		Test data:
# F1: 			0.96904		0.904330
# Precission: 		0.99772		0.975463
# Recall: 		0.94196		0.842866
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=200, total= 3.4min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100
# Iteration: 		1 		Test data:
# F1: 			0.96822		0.969492
# Precission: 		0.99663		0.996907
# Recall: 		0.94138		0.943544
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=200, total= 3.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200
# Iteration: 		3 		Test data:
# F1: 			0.96073		0.962036
# Precission: 		0.99448		0.994930
# Recall: 		0.92919		0.931248
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100, total= 1.9min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200
# Iteration: 		3 		Test data:
# F1: 			0.96158		0.898985
# Precission: 		0.99674		0.973830
# Recall: 		0.92881		0.834823
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100, total= 1.9min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200
# Iteration: 		1 		Test data:
# F1: 			0.97012		0.826147
# Precission: 		0.99752		0.883430
# Recall: 		0.94419		0.775840
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=200, total= 3.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300
# Iteration: 		0 		Test data:
# F1: 			0.78711		0.903941
# Precission: 		0.90502		0.975342
# Recall: 		0.69639		0.842280
# Iteration: 		0 		Test data:
# F1: 			0.81911		0.969409
# Precission: 		0.93713		0.996939
# Recall: 		0.72749		0.943359
# Iteration: 		2 		Test data:
# F1: 			0.72544		0.821267
# Precission: 		0.79648		0.879908
# Recall: 		0.66604		0.769954
# Iteration: 		1 		Test data:
# F1: 			0.96875		0.903941
# Precission: 		0.99770		0.975342
# Recall: 		0.94143		0.842280
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=300, total= 5.1min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300
# Iteration: 		1 		Test data:
# F1: 			0.96809		0.969409
# Precission: 		0.99668		0.996939
# Recall: 		0.94110		0.943359
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=300, total= 5.1min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300
# Iteration: 		3 		Test data:
# F1: 			0.96196		0.821267
# Precission: 		0.99575		0.879908
# Recall: 		0.93038		0.769954
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=100, total= 1.7min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100
# Iteration: 		2 		Test data:
# F1: 			0.72821		0.826808
# Precission: 		0.80046		0.883824
# Recall: 		0.66791		0.776703
# Iteration: 		2 		Test data:
# F1: 			0.81958		0.962110
# Precission: 		0.93835		0.995616
# Recall: 		0.72749		0.930786
# Iteration: 		4 		Test data:
# F1: 			0.78731		0.898321
# Precission: 		0.90528		0.974036
# Recall: 		0.69654		0.833529
# Iteration: 		4 		Test data:
# F1: 			0.72675		0.822545
# Precission: 		0.79846		0.881394
# Recall: 		0.66685		0.771063
# Iteration: 		4 		Test data:
# F1: 			0.81785		0.955034
# Precission: 		0.93668		0.993704
# Recall: 		0.72577		0.919260
# Iteration: 		3 		Test data:
# F1: 			0.96069		0.962110
# Precission: 		0.99512		0.995616
# Recall: 		0.92856		0.930786
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200, total= 3.2min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100
# Iteration: 		5 		Test data:
# F1: 			0.95254		0.955034
# Precission: 		0.99322		0.993704
# Recall: 		0.91506		0.919260
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100
# Iteration: 		5 		Test data:
# F1: 			0.96185		0.898321
# Precission: 		0.99675		0.974036
# Recall: 		0.92932		0.833529
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200, total= 3.3min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200
# Iteration: 		3 		Test data:
# F1: 			0.97052		0.826808
# Precission: 		0.99765		0.883824
# Recall: 		0.94482		0.776703
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=300, total= 5.2min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200
# Iteration: 		5 		Test data:
# F1: 			0.96266		0.822545
# Precission: 		0.99616		0.881394
# Recall: 		0.93134		0.771063
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=200, total= 3.3min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200
# Iteration: 		2 		Test data:
# F1: 			0.82046		0.962556
# Precission: 		0.94092		0.995620
# Recall: 		0.72734		0.931618
# Iteration: 		4 		Test data:
# F1: 			0.78651		0.892764
# Precission: 		0.90265		0.972539
# Recall: 		0.69684		0.825085
# Iteration: 		6 		Test data:
# F1: 			0.72651		0.818937
# Precission: 		0.79817		0.880047
# Recall: 		0.66665		0.765763
# Iteration: 		5 		Test data:
# F1: 			0.95421		0.892764
# Precission: 		0.99555		0.972539
# Recall: 		0.91617		0.825085
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300
# Iteration: 		3 		Test data:
# F1: 			0.96101		0.962556
# Precission: 		0.99526		0.995620
# Recall: 		0.92904		0.931618
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300, total= 4.8min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300
# Iteration: 		7 		Test data:
# F1: 			0.95504		0.818937
# Precission: 		0.99455		0.880047
# Recall: 		0.91855		0.765763
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300
# Iteration: 		2 		Test data:
# F1: 			0.78555		0.897994
# Precission: 		0.90363		0.974363
# Recall: 		0.69477		0.832727
# Iteration: 		2 		Test data:
# F1: 			0.72747		0.822755
# Precission: 		0.80079		0.883047
# Recall: 		0.66645		0.770169
# Iteration: 		6 		Test data:
# F1: 			0.82076		0.955312
# Precission: 		0.94037		0.993839
# Recall: 		0.72815		0.919661
# Iteration: 		4 		Test data:
# F1: 			0.78573		0.892692
# Precission: 		0.90427		0.973054
# Recall: 		0.69467		0.824592
# Iteration: 		6 		Test data:
# F1: 			0.72732		0.819187
# Precission: 		0.79912		0.880666
# Recall: 		0.66736		0.765732
# Iteration: 		3 		Test data:
# F1: 			0.96124		0.897994
# Precission: 		0.99674		0.974363
# Recall: 		0.92818		0.832727
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300, total= 4.8min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=100
# Iteration: 		7 		Test data:
# F1: 			0.95358		0.955312
# Precission: 		0.99340		0.993839
# Recall: 		0.91683		0.919661
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200, total= 3.2min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=100
# Iteration: 		5 		Test data:
# F1: 			0.95480		0.892692
# Precission: 		0.99569		0.973054
# Recall: 		0.91713		0.824592
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200, total= 3.2min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=100
# Iteration: 		3 		Test data:
# F1: 			0.96237		0.822755
# Precission: 		0.99629		0.883047
# Recall: 		0.93068		0.770169
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=300, total= 4.8min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=200
# Iteration: 		7 		Test data:
# F1: 			0.95544		0.819187
# Precission: 		0.99485		0.880666
# Recall: 		0.91903		0.765732
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=200, total= 3.2min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=200
# Iteration: 		4 		Test data:
# F1: 			0.81969		0.960685
# Precission: 		0.93755		0.995210
# Recall: 		0.72815		0.928475
# Iteration: 		8 		Test data:
# F1: 			0.78708		0.896696
# Precission: 		0.90502		0.974263
# Recall: 		0.69634		0.830570
# Iteration: 		6 		Test data:
# F1: 			0.72652		0.821384
# Precission: 		0.79842		0.881227
# Recall: 		0.66650		0.769153
# Iteration: 		5 		Test data:
# F1: 			0.95893		0.960685
# Precission: 		0.99484		0.995210
# Recall: 		0.92553		0.928475
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=200
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 12.6min
# Iteration: 		9 		Test data:
# F1: 			0.95915		0.896696
# Precission: 		0.99692		0.974263
# Recall: 		0.92414		0.830570
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=300
# Iteration: 		7 		Test data:
# F1: 			0.96093		0.821384
# Precission: 		0.99585		0.881227
# Recall: 		0.92838		0.769153
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=300
# Iteration: 		4 		Test data:
# F1: 			0.78625		0.892996
# Precission: 		0.90487		0.973346
# Recall: 		0.69512		0.824900
# Iteration: 		6 		Test data:
# F1: 			0.81963		0.954840
# Precission: 		0.93924		0.993932
# Recall: 		0.72704		0.918706
# Iteration: 		8 		Test data:
# F1: 			0.72630		0.819213
# Precission: 		0.80051		0.882033
# Recall: 		0.66468		0.764746
# Iteration: 		4 		Test data:
# F1: 			0.81980		0.960880
# Precission: 		0.93920		0.995310
# Recall: 		0.72734		0.928752
# Iteration: 		8 		Test data:
# F1: 			0.78700		0.897142
# Precission: 		0.90506		0.974044
# Recall: 		0.69619		0.831495
# Iteration: 		5 		Test data:
# F1: 			0.95475		0.892996
# Precission: 		0.99621		0.973346
# Recall: 		0.91660		0.824900
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300, total= 4.7min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=300
# Iteration: 		7 		Test data:
# F1: 			0.95271		0.954840
# Precission: 		0.99366		0.993932
# Recall: 		0.91501		0.918706
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300, total= 4.8min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# Iteration: 		5 		Test data:
# F1: 			0.95915		0.960880
# Precission: 		0.99478		0.995310
# Recall: 		0.92598		0.928752
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=200, total= 3.2min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# Iteration: 		9 		Test data:
# F1: 			0.95988		0.897142
# Precission: 		0.99700		0.974044
# Recall: 		0.92542		0.831495
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=200, total= 3.1min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100
# Iteration: 		9 		Test data:
# F1: 			0.95598		0.819213
# Precission: 		0.99529		0.882033
# Recall: 		0.91966		0.764746
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=3, min_samples_split=12, n_estimators=300, total= 4.8min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# Iteration: 		6 		Test data:
# F1: 			0.72570		0.820956
# Precission: 		0.80068		0.882634
# Recall: 		0.66356		0.767334
# Iteration: 		8 		Test data:
# F1: 			0.81708		0.954696
# Precission: 		0.93729		0.993766
# Recall: 		0.72421		0.918582
# Iteration: 		6 		Test data:
# F1: 			0.78534		0.892509
# Precission: 		0.90470		0.972318
# Recall: 		0.69381		0.824807
# Iteration: 		10 		Test data:
# F1: 			0.72656		0.818776
# Precission: 		0.80065		0.881882
# Recall: 		0.66503		0.764099
# Iteration: 		9 		Test data:
# F1: 			0.95283		0.954696
# Precission: 		0.99312		0.993766
# Recall: 		0.91569		0.918582
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# Iteration: 		7 		Test data:
# F1: 			0.96108		0.820956
# Precission: 		0.99596		0.882634
# Recall: 		0.92856		0.767334
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=200, total= 3.2min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200
# Iteration: 		7 		Test data:
# F1: 			0.95403		0.892509
# Precission: 		0.99563		0.972318
# Recall: 		0.91576		0.824807
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300
# Iteration: 		11 		Test data:
# F1: 			0.95514		0.818776
# Precission: 		0.99507		0.881882
# Recall: 		0.91829		0.764099
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300
# Iteration: 		10 		Test data:
# F1: 			0.82023		0.961190
# Precission: 		0.94142		0.995444
# Recall: 		0.72668		0.929214
# Iteration: 		8 		Test data:
# F1: 			0.78585		0.897400
# Precission: 		0.90457		0.974229
# Recall: 		0.69467		0.831803
# Iteration: 		10 		Test data:
# F1: 			0.81819		0.955254
# Precission: 		0.93901		0.993641
# Recall: 		0.72491		0.919723
# Iteration: 		11 		Test data:
# F1: 			0.95932		0.961190
# Precission: 		0.99495		0.995444
# Recall: 		0.92616		0.929214
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=300, total= 4.7min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300
# Iteration: 		9 		Test data:
# F1: 			0.96067		0.897400
# Precission: 		0.99698		0.974229
# Recall: 		0.92692		0.831803
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=300, total= 4.7min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=100
# Iteration: 		11 		Test data:
# F1: 			0.95327		0.955254
# Precission: 		0.99326		0.993641
# Recall: 		0.91637		0.919723
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, total= 3.1min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=100
# Iteration: 		6 		Test data:
# F1: 			0.72656		0.821925
# Precission: 		0.80085		0.883040
# Recall: 		0.66488		0.768721
# Iteration: 		10 		Test data:
# F1: 			0.78593		0.892907
# Precission: 		0.90626		0.973134
# Recall: 		0.69381		0.824900
# Iteration: 		8 		Test data:
# F1: 			0.72755		0.819414
# Precission: 		0.80136		0.882048
# Recall: 		0.66619		0.765085
# Iteration: 		10 		Test data:
# F1: 			0.81753		0.948682
# Precission: 		0.93805		0.992062
# Recall: 		0.72446		0.908937
# Iteration: 		12 		Test data:
# F1: 			0.78602		0.888287
# Precission: 		0.90410		0.971358
# Recall: 		0.69523		0.818305
# Iteration: 		11 		Test data:
# F1: 			0.95485		0.892907
# Precission: 		0.99566		0.973134
# Recall: 		0.91726		0.824900
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=100
# Iteration: 		11 		Test data:
# F1: 			0.94616		0.948682
# Precission: 		0.99144		0.992062
# Recall: 		0.90484		0.908937
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=200
# Iteration: 		9 		Test data:
# F1: 			0.95564		0.819414
# Precission: 		0.99469		0.882048
# Recall: 		0.91953		0.765085
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=200
# Iteration: 		7 		Test data:
# F1: 			0.96170		0.821925
# Precission: 		0.99607		0.883040
# Recall: 		0.92962		0.768721
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=8, n_estimators=300, total= 4.7min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=200
# Iteration: 		13 		Test data:
# F1: 			0.94746		0.888287
# Precission: 		0.99430		0.971358
# Recall: 		0.90484		0.818305
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=300
# Iteration: 		8 		Test data:
# F1: 			0.81932		0.955301
# Precission: 		0.94020		0.994102
# Recall: 		0.72598		0.919414
# Iteration: 		12 		Test data:
# F1: 			0.78560		0.893077
# Precission: 		0.90625		0.973281
# Recall: 		0.69330		0.825085
# Iteration: 		12 		Test data:
# F1: 			0.72657		0.815691
# Precission: 		0.80161		0.881101
# Recall: 		0.66437		0.759322
# Iteration: 		13 		Test data:
# F1: 			0.94868		0.815691
# Precission: 		0.99336		0.881101
# Recall: 		0.90785		0.759322
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=300
# Iteration: 		9 		Test data:
# F1: 			0.95308		0.955301
# Precission: 		0.99369		0.994102
# Recall: 		0.91566		0.919414
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=300
# Iteration: 		13 		Test data:
# F1: 			0.95511		0.893077
# Precission: 		0.99580		0.973281
# Recall: 		0.91761		0.825085
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100
# Iteration: 		12 		Test data:
# F1: 			0.72797		0.819587
# Precission: 		0.80222		0.882654
# Recall: 		0.66630		0.764931
# Iteration: 		12 		Test data:
# F1: 			0.82007		0.949547
# Precission: 		0.94023		0.992705
# Recall: 		0.72714		0.909985
# Iteration: 		10 		Test data:
# F1: 			0.78256		0.887315
# Precission: 		0.90325		0.971511
# Recall: 		0.69032		0.816549
# Iteration: 		8 		Test data:
# F1: 			0.72705		0.816589
# Precission: 		0.80338		0.882698
# Recall: 		0.66397		0.759692
# Iteration: 		14 		Test data:
# F1: 			0.81726		0.947668
# Precission: 		0.93673		0.992013
# Recall: 		0.72481		0.907119
# Iteration: 		13 		Test data:
# F1: 			0.94721		0.949547
# Precission: 		0.99219		0.992705
# Recall: 		0.90613		0.909985
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100
# Iteration: 		13 		Test data:
# F1: 			0.95573		0.819587
# Precission: 		0.99507		0.882654
# Recall: 		0.91938		0.764931
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300, total= 4.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100
# Iteration: 		11 		Test data:
# F1: 			0.94820		0.887315
# Precission: 		0.99459		0.971511
# Recall: 		0.90595		0.816549
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=200
# Iteration: 		15 		Test data:
# F1: 			0.94525		0.947668
# Precission: 		0.99145		0.992013
# Recall: 		0.90317		0.907119
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=200
# Iteration: 		9 		Test data:
# F1: 			0.94967		0.816589
# Precission: 		0.99419		0.882698
# Recall: 		0.90896		0.759692
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=200
# Iteration: 		14 		Test data:
# F1: 			0.81974		0.949461
# Precission: 		0.94013		0.992737
# Recall: 		0.72668		0.909800
# Iteration: 		14 		Test data:
# F1: 			0.78339		0.886267
# Precission: 		0.90312		0.971487
# Recall: 		0.69169		0.814792
# Iteration: 		14 		Test data:
# F1: 			0.72589		0.814847
# Precission: 		0.79995		0.879919
# Recall: 		0.66437		0.758737
# Iteration: 		15 		Test data:
# F1: 			0.94673		0.886267
# Precission: 		0.99471		0.971487
# Recall: 		0.90317		0.814792
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=300
# Iteration: 		15 		Test data:
# F1: 			0.94704		0.949461
# Precission: 		0.99227		0.992737
# Recall: 		0.90575		0.909800
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=300
# Iteration: 		15 		Test data:
# F1: 			0.94847		0.814847
# Precission: 		0.99314		0.879919
# Recall: 		0.90765		0.758737
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=300
# Iteration: 		14 		Test data:
# F1: 			0.78541		0.888457
# Precission: 		0.90538		0.972549
# Recall: 		0.69351		0.817750
# Iteration: 		10 		Test data:
# F1: 			0.72779		0.817167
# Precission: 		0.80304		0.882221
# Recall: 		0.66544		0.761048
# Iteration: 		12 		Test data:
# F1: 			0.81932		0.948109
# Precission: 		0.94073		0.992020
# Recall: 		0.72567		0.907920
# Iteration: 		16 		Test data:
# F1: 			0.78413		0.886964
# Precission: 		0.90448		0.971979
# Recall: 		0.69204		0.815624
# Iteration: 		10 		Test data:
# F1: 			0.72685		0.815687
# Precission: 		0.80192		0.881215
# Recall: 		0.66463		0.759230
# Iteration: 		15 		Test data:
# F1: 			0.94895		0.888457
# Precission: 		0.99525		0.972549
# Recall: 		0.90676		0.817750
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# Iteration: 		13 		Test data:
# F1: 			0.94570		0.948109
# Precission: 		0.99151		0.992020
# Recall: 		0.90393		0.907920
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=200, total= 2.9min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# Iteration: 		17 		Test data:
# F1: 			0.94745		0.886964
# Precission: 		0.99477		0.971979
# Recall: 		0.90444		0.815624
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=200, total= 2.9min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# Iteration: 		11 		Test data:
# F1: 			0.94994		0.817167
# Precission: 		0.99381		0.882221
# Recall: 		0.90977		0.761048
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=4, min_samples_split=12, n_estimators=300, total= 4.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# Iteration: 		11 		Test data:
# F1: 			0.94871		0.815687
# Precission: 		0.99314		0.881215
# Recall: 		0.90808		0.759230
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=200, total= 2.9min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# Iteration: 		16 		Test data:
# F1: 			0.81715		0.947545
# Precission: 		0.93654		0.992111
# Recall: 		0.72476		0.906810
# Iteration: 		14 		Test data:
# F1: 			0.78518		0.887315
# Precission: 		0.90445		0.971685
# Recall: 		0.69371		0.816425
# Iteration: 		18 		Test data:
# F1: 			0.72553		0.814898
# Precission: 		0.80227		0.881703
# Recall: 		0.66220		0.757504
# Iteration: 		17 		Test data:
# F1: 			0.94527		0.947545
# Precission: 		0.99172		0.992111
# Recall: 		0.90297		0.906810
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# Iteration: 		15 		Test data:
# F1: 			0.94717		0.887315
# Precission: 		0.99515		0.971685
# Recall: 		0.90360		0.816425
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# Iteration: 		19 		Test data:
# F1: 			0.94779		0.814898
# Precission: 		0.99343		0.881703
# Recall: 		0.90616		0.757504
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# Iteration: 		16 		Test data:
# F1: 			0.81851		0.948696
# Precission: 		0.94028		0.992460
# Recall: 		0.72466		0.908629
# Iteration: 		16 		Test data:
# F1: 			0.78598		0.888171
# Precission: 		0.90649		0.972429
# Recall: 		0.69376		0.817350
# Iteration: 		16 		Test data:
# F1: 			0.72583		0.814810
# Precission: 		0.80085		0.880538
# Recall: 		0.66367		0.758213
# Iteration: 		12 		Test data:
# F1: 			0.81734		0.948829
# Precission: 		0.93814		0.992861
# Recall: 		0.72410		0.908536
# Iteration: 		12 		Test data:
# F1: 			0.78620		0.888152
# Precission: 		0.90586		0.972428
# Recall: 		0.69447		0.817319
# Iteration: 		17 		Test data:
# F1: 			0.94613		0.948696
# Precission: 		0.99176		0.992460
# Recall: 		0.90451		0.908629
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# Iteration: 		17 		Test data:
# F1: 			0.94777		0.888171
# Precission: 		0.99508		0.972429
# Recall: 		0.90476		0.817350
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=100
# Iteration: 		13 		Test data:
# F1: 			0.94627		0.948829
# Precission: 		0.99226		0.992861
# Recall: 		0.90436		0.908536
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200, total= 2.9min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=100
# Iteration: 		17 		Test data:
# F1: 			0.94825		0.814810
# Precission: 		0.99346		0.880538
# Recall: 		0.90696		0.758213
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=100
# Iteration: 		13 		Test data:
# F1: 			0.94776		0.888152
# Precission: 		0.99530		0.972428
# Recall: 		0.90456		0.817319
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200, total= 2.9min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=200
# Iteration: 		18 		Test data:
# F1: 			0.72557		0.815043
# Precission: 		0.79963		0.879961
# Recall: 		0.66407		0.759045
# Iteration: 		18 		Test data:
# F1: 			0.81595		0.943391
# Precission: 		0.93709		0.990842
# Recall: 		0.72254		0.900277
# Iteration: 		14 		Test data:
# F1: 			0.78362		0.883776
# Precission: 		0.90134		0.970368
# Recall: 		0.69310		0.811371
# Iteration: 		18 		Test data:
# F1: 			0.72583		0.813061
# Precission: 		0.80165		0.880157
# Recall: 		0.66311		0.755470
# Iteration: 		19 		Test data:
# F1: 			0.94064		0.943391
# Precission: 		0.99019		0.990842
# Recall: 		0.89581		0.900277
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=200
# Iteration: 		19 		Test data:
# F1: 			0.94852		0.815043
# Precission: 		0.99349		0.879961
# Recall: 		0.90744		0.759045
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=200
# Iteration: 		15 		Test data:
# F1: 			0.94257		0.883776
# Precission: 		0.99408		0.970368
# Recall: 		0.89614		0.811371
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=300
# Iteration: 		19 		Test data:
# F1: 			0.94335		0.813061
# Precission: 		0.99164		0.880157
# Recall: 		0.89955		0.755470
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=300
# Iteration: 		16 		Test data:
# F1: 			0.81916		0.948322
# Precission: 		0.93953		0.992820
# Recall: 		0.72613		0.907643
# Iteration: 		20 		Test data:
# F1: 			0.78572		0.887873
# Precission: 		0.90544		0.972587
# Recall: 		0.69396		0.816733
# Iteration: 		14 		Test data:
# F1: 			0.81826		0.943401
# Precission: 		0.93996		0.990976
# Recall: 		0.72446		0.900185
# Iteration: 		17 		Test data:
# F1: 			0.94569		0.948322
# Precission: 		0.99198		0.992820
# Recall: 		0.90353		0.907643
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=300
# Iteration: 		21 		Test data:
# F1: 			0.94747		0.887873
# Precission: 		0.99494		0.972587
# Recall: 		0.90433		0.816733
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=100
# Iteration: 		15 		Test data:
# F1: 			0.94077		0.943401
# Precission: 		0.99044		0.990976
# Recall: 		0.89584		0.900185
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=200, total= 2.9min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=100
# Iteration: 		18 		Test data:
# F1: 			0.72591		0.815103
# Precission: 		0.80155		0.880974
# Recall: 		0.66331		0.758398
# Iteration: 		20 		Test data:
# F1: 			0.78304		0.882592
# Precission: 		0.90479		0.971315
# Recall: 		0.69017		0.808721
# Iteration: 		20 		Test data:
# F1: 			0.72731		0.813518
# Precission: 		0.80423		0.881606
# Recall: 		0.66382		0.755193
# Iteration: 		22 		Test data:
# F1: 			0.81927		0.968828
# Precission: 		0.93738		0.996708
# Recall: 		0.72759		0.942465
# Iteration: 		16 		Test data:
# F1: 			0.78735		0.903519
# Precission: 		0.90556		0.974980
# Recall: 		0.69644		0.841818
# Iteration: 		21 		Test data:
# F1: 			0.94213		0.882592
# Precission: 		0.99396		0.971315
# Recall: 		0.89543		0.808721
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=200, total= 2.9min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=100
# Iteration: 		19 		Test data:
# F1: 			0.94836		0.815103
# Precission: 		0.99311		0.880974
# Recall: 		0.90747		0.758398
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=10, n_estimators=300, total= 4.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=200
# Iteration: 		21 		Test data:
# F1: 			0.94355		0.813518
# Precission: 		0.99186		0.881606
# Recall: 		0.89973		0.755193
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=200
# Iteration: 		23 		Test data:
# F1: 			0.96752		0.968828
# Precission: 		0.99652		0.996708
# Recall: 		0.94017		0.942465
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=200
# Iteration: 		17 		Test data:
# F1: 			0.96843		0.903519
# Precission: 		0.99740		0.974980
# Recall: 		0.94110		0.841818
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=300
# Iteration: 		16 		Test data:
# F1: 			0.82018		0.943126
# Precission: 		0.94077		0.990704
# Recall: 		0.72699		0.899908
# Iteration: 		20 		Test data:
# F1: 			0.78361		0.882774
# Precission: 		0.90483		0.971045
# Recall: 		0.69103		0.809214
# Iteration: 		22 		Test data:
# F1: 			0.72839		0.826871
# Precission: 		0.80333		0.885530
# Recall: 		0.66625		0.775501
# Iteration: 		17 		Test data:
# F1: 			0.94059		0.943126
# Precission: 		0.99013		0.990704
# Recall: 		0.89576		0.899908
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=300
# Iteration: 		23 		Test data:
# F1: 			0.97007		0.826871
# Precission: 		0.99701		0.885530
# Recall: 		0.94454		0.775501
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=300
# Iteration: 		21 		Test data:
# F1: 			0.94245		0.882774
# Precission: 		0.99411		0.971045
# Recall: 		0.89589		0.809214
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100
# Iteration: 		18 		Test data:
# F1: 			0.72749		0.813909
# Precission: 		0.80387		0.881518
# Recall: 		0.66437		0.755932
# Iteration: 		20 		Test data:
# F1: 			0.82004		0.969002
# Precission: 		0.93882		0.996904
# Recall: 		0.72795		0.942619
# Iteration: 		22 		Test data:
# F1: 			0.78711		0.903321
# Precission: 		0.90613		0.975346
# Recall: 		0.69573		0.841202
# Iteration: 		24 		Test data:
# F1: 			0.72830		0.826840
# Precission: 		0.80208		0.884817
# Recall: 		0.66695		0.775994
# Iteration: 		22 		Test data:
# F1: 			0.81883		0.961025
# Precission: 		0.93698		0.995410
# Recall: 		0.72714		0.928937
# Iteration: 		19 		Test data:
# F1: 			0.94374		0.813909
# Precission: 		0.99219		0.881518
# Recall: 		0.89981		0.755932
# [CV]  bootstrap=True, max_depth=80, max_features=sqrt, min_samples_leaf=5, min_samples_split=12, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100
# Iteration: 		21 		Test data:
# F1: 			0.96779		0.969002
# Precission: 		0.99665		0.996904
# Recall: 		0.94055		0.942619
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100
# Iteration: 		23 		Test data:
# F1: 			0.96855		0.903321
# Precission: 		0.99759		0.975346
# Recall: 		0.94115		0.841202
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=200
# Iteration: 		23 		Test data:
# F1: 			0.95956		0.961025
# Precission: 		0.99508		0.995410
# Recall: 		0.92649		0.928937
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=200
# Iteration: 		25 		Test data:
# F1: 			0.97004		0.826840
# Precission: 		0.99720		0.884817
# Recall: 		0.94432		0.775994
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=200
# Iteration: 		18 		Test data:
# F1: 			0.82128		0.969096
# Precission: 		0.93978		0.997034
# Recall: 		0.72931		0.942681
# Iteration: 		20 		Test data:
# F1: 			0.78581		0.898102
# Precission: 		0.90379		0.974025
# Recall: 		0.69507		0.833159
# Iteration: 		22 		Test data:
# F1: 			0.72907		0.824150
# Precission: 		0.80147		0.883429
# Recall: 		0.66867		0.772327
# Iteration: 		21 		Test data:
# F1: 			0.96168		0.898102
# Precission: 		0.99650		0.974025
# Recall: 		0.92922		0.833159
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=300
# Iteration: 		23 		Test data:
# F1: 			0.96331		0.824150
# Precission: 		0.99646		0.883429
# Recall: 		0.93230		0.772327
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=300
# Iteration: 		19 		Test data:
# F1: 			0.96794		0.969096
# Precission: 		0.99676		0.997034
# Recall: 		0.94075		0.942681
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=300, total= 4.4min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=300
# Iteration: 		18 		Test data:
# F1: 			0.78686		0.903765
# Precission: 		0.90536		0.975470
# Recall: 		0.69578		0.841880
# Iteration: 		24 		Test data:
# F1: 			0.72896		0.827395
# Precission: 		0.80155		0.884567
# Recall: 		0.66842		0.777165
# Iteration: 		24 		Test data:
# F1: 			0.78656		0.899172
# Precission: 		0.90570		0.974731
# Recall: 		0.69512		0.834484
# Iteration: 		24 		Test data:
# F1: 			0.81996		0.962475
# Precission: 		0.93928		0.995586
# Recall: 		0.72754		0.931495
# Iteration: 		26 		Test data:
# F1: 			0.72868		0.823990
# Precission: 		0.80263		0.884273
# Recall: 		0.66721		0.771402
# Iteration: 		19 		Test data:
# F1: 			0.96894		0.903765
# Precission: 		0.99764		0.975470
# Recall: 		0.94184		0.841880
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=300, total= 4.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=100
# Iteration: 		25 		Test data:
# F1: 			0.96209		0.899172
# Precission: 		0.99667		0.974731
# Recall: 		0.92983		0.834484
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=100
# Iteration: 		25 		Test data:
# F1: 			0.96088		0.962475
# Precission: 		0.99510		0.995586
# Recall: 		0.92894		0.931495
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=100
# Iteration: 		25 		Test data:
# F1: 			0.97042		0.827395
# Precission: 		0.99733		0.884567
# Recall: 		0.94492		0.777165
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=300, total= 4.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=200
# Iteration: 		27 		Test data:
# F1: 			0.96297		0.823990
# Precission: 		0.99648		0.884273
# Recall: 		0.93165		0.771402
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=200, total= 3.0min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=200
# Iteration: 		20 		Test data:
# F1: 			0.81912		0.954241
# Precission: 		0.93824		0.993826
# Recall: 		0.72684		0.917689
# Iteration: 		26 		Test data:
# F1: 			0.78555		0.892364
# Precission: 		0.90302		0.971931
# Recall: 		0.69512		0.824838
# Iteration: 		26 		Test data:
# F1: 			0.72616		0.818788
# Precission: 		0.80084		0.881828
# Recall: 		0.66422		0.764160
# Iteration: 		21 		Test data:
# F1: 			0.95235		0.954241
# Precission: 		0.99341		0.993826
# Recall: 		0.91455		0.917689
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=200
# Iteration: 		27 		Test data:
# F1: 			0.95437		0.892364
# Precission: 		0.99577		0.971931
# Recall: 		0.91627		0.824838
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=300
# Iteration: 		27 		Test data:
# F1: 			0.95586		0.818788
# Precission: 		0.99461		0.881828
# Recall: 		0.92001		0.764160
# [CV]  bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=80, max_features=log2, min_samples_leaf=3, min_samples_split=12, n_estimators=300
# Iteration: 		22 		Test data:
# F1: 			0.81939		0.962664
# Precission: 		0.93938		0.995392
# Recall: 		0.72658		0.932018
# Iteration: 		24 		Test data:
# F1: 			0.78677		0.898760
# Precission: 		0.90540		0.974436
# Recall: 		0.69563		0.833991
# ...
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=200, total= 3.2min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=100
# Iteration: 		168 		Test data:
# F1: 			0.78467		0.888528
# Precission: 		0.90402		0.972414
# Recall: 		0.69315		0.817966
# Iteration: 		150 		Test data:
# F1: 			0.72645		0.819053
# Precission: 		0.80170		0.882483
# Recall: 		0.66412		0.764129
# Iteration: 		169 		Test data:
# F1: 			0.94871		0.888528
# Precission: 		0.99506		0.972414
# Recall: 		0.90648		0.817966
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=200, total= 3.2min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=100
# Iteration: 		154 		Test data:
# F1: 			0.72723		0.816324
# Precission: 		0.80234		0.881581
# Recall: 		0.66498		0.760062
# Iteration: 		156 		Test data:
# F1: 			0.81675		0.947235
# Precission: 		0.93649		0.991873
# Recall: 		0.72416		0.906441
# Iteration: 		148 		Test data:
# F1: 			0.78502		0.887265
# Precission: 		0.90581		0.972484
# Recall: 		0.69265		0.815778
# Iteration: 		151 		Test data:
# F1: 			0.95592		0.819053
# Precission: 		0.99508		0.882483
# Recall: 		0.91973		0.764129
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=4, min_samples_split=10, n_estimators=300, total= 4.9min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=200
# Iteration: 		155 		Test data:
# F1: 			0.94996		0.816324
# Precission: 		0.99359		0.881581
# Recall: 		0.91000		0.760062
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=200, total= 3.2min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=200
# Iteration: 		157 		Test data:
# F1: 			0.94480		0.947235
# Precission: 		0.99125		0.991873
# Recall: 		0.90251		0.906441
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=200
# Iteration: 		149 		Test data:
# F1: 			0.94676		0.887265
# Precission: 		0.99474		0.972484
# Recall: 		0.90320		0.815778
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=300
# Iteration: 		170 		Test data:
# F1: 			0.72607		0.815071
# Precission: 		0.80048		0.880110
# Recall: 		0.66432		0.758983
# Iteration: 		171 		Test data:
# F1: 			0.94784		0.815071
# Precission: 		0.99324		0.880110
# Recall: 		0.90641		0.758983
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=100, total= 1.7min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=300
# Iteration: 		150 		Test data:
# F1: 			0.81935		0.948566
# Precission: 		0.94002		0.992691
# Recall: 		0.72613		0.908197
# Iteration: 		162 		Test data:
# F1: 			0.78535		0.888956
# Precission: 		0.90548		0.972785
# Recall: 		0.69335		0.818428
# Iteration: 		163 		Test data:
# F1: 			0.94910		0.888956
# Precission: 		0.99528		0.972785
# Recall: 		0.90701		0.818428
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=300, total= 4.9min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=300
# Iteration: 		151 		Test data:
# F1: 			0.94633		0.948566
# Precission: 		0.99221		0.992691
# Recall: 		0.90451		0.908197
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=300, total= 4.9min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# Iteration: 		142 		Test data:
# F1: 			0.72753		0.816754
# Precission: 		0.80477		0.883251
# Recall: 		0.66382		0.759569
# Iteration: 		152 		Test data:
# F1: 			0.81753		0.947784
# Precission: 		0.93975		0.992081
# Recall: 		0.72345		0.907273
# Iteration: 		156 		Test data:
# F1: 			0.78550		0.888595
# Precission: 		0.90529		0.972487
# Recall: 		0.69371		0.818028
# Iteration: 		158 		Test data:
# F1: 			0.72657		0.815475
# Precission: 		0.80249		0.881426
# Recall: 		0.66377		0.758706
# Iteration: 		152 		Test data:
# F1: 			0.81677		0.947692
# Precission: 		0.93790		0.991881
# Recall: 		0.72335		0.907273
# Iteration: 		153 		Test data:
# F1: 			0.94527		0.947784
# Precission: 		0.99148		0.992081
# Recall: 		0.90317		0.907273
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=200, total= 3.5min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# Iteration: 		157 		Test data:
# F1: 			0.94768		0.888595
# Precission: 		0.99466		0.972487
# Recall: 		0.90494		0.818028
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=200, total= 3.5min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100
# Iteration: 		143 		Test data:
# F1: 			0.94981		0.816754
# Precission: 		0.99351		0.883251
# Recall: 		0.90980		0.759569
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=4, min_samples_split=12, n_estimators=300, total= 5.1min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# Iteration: 		159 		Test data:
# F1: 			0.94798		0.815475
# Precission: 		0.99319		0.881426
# Recall: 		0.90671		0.758706
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=200, total= 3.5min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# Iteration: 		153 		Test data:
# F1: 			0.94526		0.947692
# Precission: 		0.99131		0.991881
# Recall: 		0.90330		0.907273
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100, total= 1.7min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200
# Iteration: 		150 		Test data:
# F1: 			0.81825		0.948364
# Precission: 		0.94055		0.991991
# Recall: 		0.72410		0.908413
# Iteration: 		154 		Test data:
# F1: 			0.78461		0.887649
# Precission: 		0.90363		0.972226
# Recall: 		0.69330		0.816610
# Iteration: 		158 		Test data:
# F1: 			0.72505		0.814828
# Precission: 		0.79800		0.879090
# Recall: 		0.66432		0.759322
# Iteration: 		155 		Test data:
# F1: 			0.94735		0.887649
# Precission: 		0.99494		0.972226
# Recall: 		0.90411		0.816610
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# Iteration: 		159 		Test data:
# F1: 			0.94906		0.814828
# Precission: 		0.99350		0.879090
# Recall: 		0.90843		0.759322
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=100, total= 1.6min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# Iteration: 		151 		Test data:
# F1: 			0.94590		0.948364
# Precission: 		0.99157		0.991991
# Recall: 		0.90426		0.908413
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=300, total= 5.0min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300
# Iteration: 		172 		Test data:
# F1: 			0.78472		0.888089
# Precission: 		0.90442		0.972146
# Recall: 		0.69300		0.817411
# Iteration: 		173 		Test data:
# F1: 			0.94805		0.888089
# Precission: 		0.99467		0.972146
# Recall: 		0.90560		0.817411
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=300, total= 4.9min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=100
# [Parallel(n_jobs=-1)]: Done 632 tasks      | elapsed: 279.3min
# Iteration: 		164 		Test data:
# F1: 			0.72761		0.816382
# Precission: 		0.80319		0.881966
# Recall: 		0.66503		0.759877
# Iteration: 		144 		Test data:
# F1: 			0.81889		0.947429
# Precission: 		0.93991		0.991710
# Recall: 		0.72547		0.906934
# Iteration: 		160 		Test data:
# F1: 			0.78449		0.887836
# Precission: 		0.90371		0.972062
# Recall: 		0.69305		0.817042
# Iteration: 		154 		Test data:
# F1: 			0.72724		0.816080
# Precission: 		0.80243		0.881386
# Recall: 		0.66493		0.759784
# Iteration: 		145 		Test data:
# F1: 			0.94512		0.947429
# Precission: 		0.99128		0.991710
# Recall: 		0.90307		0.906934
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200, total= 3.1min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=100
# Iteration: 		161 		Test data:
# F1: 			0.94791		0.887836
# Precission: 		0.99483		0.972062
# Recall: 		0.90522		0.817042
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200, total= 3.1min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=100
# Iteration: 		165 		Test data:
# F1: 			0.94859		0.816382
# Precission: 		0.99317		0.881966
# Recall: 		0.90785		0.759877
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=300, total= 4.9min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=200
# Iteration: 		155 		Test data:
# F1: 			0.94848		0.816080
# Precission: 		0.99284		0.881386
# Recall: 		0.90793		0.759784
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=200, total= 3.2min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=200
# Iteration: 		174 		Test data:
# F1: 			0.81721		0.942275
# Precission: 		0.93795		0.990622
# Recall: 		0.72400		0.898428
# Iteration: 		175 		Test data:
# F1: 			0.93984		0.942275
# Precission: 		0.99006		0.990622
# Recall: 		0.89447		0.898428
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=200
# Iteration: 		146 		Test data:
# F1: 			0.78481		0.884004
# Precission: 		0.90388		0.971185
# Recall: 		0.69346		0.811186
# Iteration: 		162 		Test data:
# F1: 			0.72493		0.812228
# Precission: 		0.79945		0.878915
# Recall: 		0.66311		0.754946
# Iteration: 		147 		Test data:
# F1: 			0.94229		0.884004
# Precission: 		0.99361		0.971185
# Recall: 		0.89601		0.811186
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=300
# Iteration: 		163 		Test data:
# F1: 			0.94326		0.812228
# Precission: 		0.99199		0.878915
# Recall: 		0.89910		0.754946
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=100, total= 1.5min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=300
# Iteration: 		156 		Test data:
# F1: 			0.81914		0.947550
# Precission: 		0.94041		0.992011
# Recall: 		0.72557		0.906903
# Iteration: 		160 		Test data:
# F1: 			0.78527		0.888472
# Precission: 		0.90580		0.972933
# Recall: 		0.69305		0.817504
# Iteration: 		152 		Test data:
# F1: 			0.72884		0.816911
# Precission: 		0.80539		0.883284
# Recall: 		0.66559		0.759815
# Iteration: 		166 		Test data:
# F1: 			0.81801		0.942904
# Precission: 		0.94075		0.991000
# Recall: 		0.72360		0.899260
# Iteration: 		156 		Test data:
# F1: 			0.78531		0.884606
# Precission: 		0.90392		0.971534
# Recall: 		0.69421		0.811957
# Iteration: 		157 		Test data:
# F1: 			0.94517		0.947550
# Precission: 		0.99145		0.992011
# Recall: 		0.90302		0.906903
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300, total= 4.6min
# [CV] bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=300
# Iteration: 		161 		Test data:
# F1: 			0.94841		0.888472
# Precission: 		0.99514		0.972933
# Recall: 		0.90588		0.817504
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300, total= 4.6min
# Iteration: 		167 		Test data:
# F1: 			0.94048		0.942904
# Precission: 		0.99057		0.991000
# Recall: 		0.89521		0.899260
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=200, total= 3.0min
# Iteration: 		153 		Test data:
# F1: 			0.94847		0.816911
# Precission: 		0.99336		0.883284
# Recall: 		0.90747		0.759815
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=10, n_estimators=300, total= 4.6min
# Iteration: 		157 		Test data:
# F1: 			0.94273		0.884606
# Precission: 		0.99397		0.971534
# Recall: 		0.89652		0.811957
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=200, total= 3.0min
# Iteration: 		176 		Test data:
# F1: 			0.72783		0.814438
# Precission: 		0.80402		0.881920
# Recall: 		0.66483		0.756549
# Iteration: 		177 		Test data:
# F1: 			0.94410		0.814438
# Precission: 		0.99253		0.881920
# Recall: 		0.90019		0.756549
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=200, total= 2.8min
# Iteration: 		148 		Test data:
# F1: 			0.81783		0.943288
# Precission: 		0.94044		0.991174
# Recall: 		0.72350		0.899815
# Iteration: 		164 		Test data:
# F1: 			0.78626		0.884422
# Precission: 		0.90592		0.971664
# Recall: 		0.69452		0.811556
# Iteration: 		149 		Test data:
# F1: 			0.94074		0.943288
# Precission: 		0.99063		0.991174
# Recall: 		0.89564		0.899815
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=300, total= 3.4min
# Iteration: 		165 		Test data:
# F1: 			0.94243		0.884422
# Precission: 		0.99391		0.971664
# Recall: 		0.89601		0.811556
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=300, total= 3.4min
# Iteration: 		158 		Test data:
# F1: 			0.72800		0.814033
# Precission: 		0.80510		0.881976
# Recall: 		0.66437		0.755809
# Iteration: 		159 		Test data:
# F1: 			0.94389		0.814033
# Precission: 		0.99206		0.881976
# Recall: 		0.90019		0.755809
# [CV]  bootstrap=True, max_depth=110, max_features=log2, min_samples_leaf=5, min_samples_split=12, n_estimators=300, total= 2.7min
# [Parallel(n_jobs=-1)]: Done 648 out of 648 | elapsed: 286.1min finished
# GridSearchCV(cv=3, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'bootstrap': [True], 'max_depth': [80, 90, 100, 110], 'max_features': ['sqrt', 'log2'], 'min_samples_leaf': [3, 4, 5], 'min_samples_split': [8, 10, 12], 'n_estimators': [100, 200, 300]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=<function evaluate at 0x127fd0ea0>, verbose=2)

# %%
try:
    best_params = grid_search.best_params_
except NameError:
    best_params = {'bootstrap': True,
 'max_depth': 80,
 'max_features': 'log2',
 'min_samples_leaf': 3,
 'min_samples_split': 8,
 'n_estimators': 300}

# %%
# Out:
# {'bootstrap': True,
#  'max_depth': 80,
#  'max_features': 'log2',
#  'min_samples_leaf': 3,
#  'min_samples_split': 8,
#  'n_estimators': 300}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5df6c97d17ba> in <module>()
#       1 from sklearn.model_selection import cross_val_predict
#       2 clf = RandomForestClassifier(**best_params)
# ----> 3 predicted = cross_val_predict(clf, X_flat, Y_flat, cv=3)
#       4 accuracy_score(iris.target, predicted)
#
# NameError: name 'X_flat' is not defined

# %%
test_image_bands = bands[test_date_index]
reshaper = Reshaper(test_image_bands.shape)

X_flat = reshaper.flatten_data(test_image_bands)
Y_flat = reshaper.flatten_labels(mask_2016)

X_train, X_test, Y_train, Y_test = train_test_split(X_flat, Y_flat, train_size=0.5, shuffle=False)


from sklearn.model_selection import cross_val_predict
clf = RandomForestClassifier(**best_params)
predicted = cross_val_predict(clf, X_flat, Y_flat, cv=3)
accuracy_score(Y_flat, predicted)
# Out:
# /Users/joosko/work/ijs/ml/SentinelHub/venv/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3ebca95f316d> in <module>()
#      11 clf = RandomForestClassifier(**best_params)
#      12 predicted = cross_val_predict(clf, X_flat, Y_flat, cv=3)
# ---> 13 accuracy_score(Y_flat, predicted)
#
# NameError: name 'accuracy_score' is not defined

# %%
print("prec:", precision_score(Y_flat, predicted))
print("rec:", recall_score(Y_flat, predicted))
print("f1:", f1_score(Y_flat, predicted))
# Out:
# prec: 0.8787511689194933
# rec: 0.6970631869984489
# f1: 0.7774330625752106

# %%
from sklearn.model_selection import cross_val_predict

testing_dates = [(2016, 3, 12), (2016, 4,1), (2016, 4,11), (2016, 4, 21), (2016,5, 1), (2016, 5, 11)]

testing_dates = list(map(lambda x: datetime.datetime(year=x[0], month=x[1], day=x[2]), 
                         testing_dates))

classifiers = []
predictions = []
for date in testing_dates:
    print("start", date)
    date_ind = find_index_after_date(dates_full, date)
    image = bands[date_ind]
    X_flat = reshaper.flatten_data(image)
    Y_flat = reshaper.flatten_labels(mask_2016)
    clf = RandomForestClassifier(**best_params)
    classifiers.append(clf)
    predicted = cross_val_predict(clf, X_flat, Y_flat, cv=3)
    predictions.append(predicted)
    print("prec:", precision_score(Y_flat, predicted))
    print("rec:", recall_score(Y_flat, predicted))
    print("f1:", f1_score(Y_flat, predicted))
# Out:
# start 2016-03-12 00:00:00
# prec: 0.5166342512027843
# rec: 0.34034661811315664
# f1: 0.4103585657370518
# start 2016-04-01 00:00:00
# prec: 0.6535930297620633
# rec: 0.41354777800256254
# f1: 0.506572222164858
# start 2016-04-11 00:00:00
# prec: 0.7747864290944594
# rec: 0.5351507181873356
# f1: 0.6330494784915143
# start 2016-04-21 00:00:00
# prec: 0.7793449119944049
# rec: 0.5635916110324365
# f1: 0.654137030260931
# start 2016-05-01 00:00:00
# prec: 0.7609361066255332
# rec: 0.5322678535302448
# f1: 0.6263850724652057
# start 2016-05-11 00:00:00
# prec: 0.8791472719930286
# rec: 0.6973329287207499
# f1: 0.7777558407370846

# %%
last_prediction = predictions[-1]
def revert(data):
    return reshaper.revert_labels_shape(data)
true_pos = last_prediction & Y_flat
false_pos = (last_prediction == 1) & (Y_flat == 0)
false_neg = (last_prediction == 0) & (Y_flat == 1)
testing_true_c = true_c_full[find_index_after_date(dates_full,testing_dates[-1])]

overlay_cloud_mask(testing_true_c, [revert(true_pos) , revert(false_pos), revert(false_neg)], 
                   mask_maps=[[128,0,128], [255, 0,0], [0,0,255]],figsize=(11,11))
plt.savefig(f"may_classification.png", bbox_inches='tight', pad_inches=0)

# %%
clf = RandomForestClassifier(**best_params)

date_ind = find_index_after_date(dates_full,testing_dates[-1])
image = bands[date_ind]

X_flat = reshaper.flatten_data(image)
Y_flat = reshaper.flatten_labels(mask_arra)

last_pred = cross_val_predict(clf, X_flat, Y_flat, cv=3)

# %%
def revert(data):
    return reshaper.revert_labels_shape(data)

true_pos = last_pred & Y_flat
false_pos = (last_pred == 1) & (Y_flat == 0)
false_neg = (last_pred == 0) & (Y_flat == 1)
testing_true_c = true_c_full[date_ind]

overlay_cloud_mask(testing_true_c, [revert(true_pos) , revert(false_pos), revert(false_neg)], 
                   mask_maps=[[128,0,128], [0, 0,255], [255,0,0]],figsize=(11,11))
plt.savefig(f"may_classification_ar_land.png", bbox_inches='tight', pad_inches=0)
predicted = last_pred
print("prec:", precision_score(Y_flat, predicted))
print("rec:", recall_score(Y_flat, predicted))
print("f1:", f1_score(Y_flat, predicted))
# Out:
# prec: 0.9067918561682774
# rec: 0.9149804828423793
# f1: 0.9108677661062394

# %%
from sklearn.model_selection import cross_val_predict

testing_dates = [(2016, 3, 12), (2016, 4,1), (2016, 4,11), (2016, 4, 21), (2016,5, 1), (2016, 5, 11)]

testing_dates = list(map(lambda x: datetime.datetime(year=x[0], month=x[1], day=x[2]), 
                         testing_dates))0

classifiers_ara = []
predictions_ara = []
for date in testing_dates:
    print("start", date)
    date_ind = find_index_after_date(dates_full, date)
    image = bands[date_ind]
    X_flat = reshaper.flatten_data(image)
    Y_flat = reshaper.flatten_labels(mask_arra)
    clf = RandomForestClassifier(**best_params)
    classifiers_ara.append(clf)
    predicted = cross_val_predict(clf, X_flat, Y_flat, cv=3)
    predictions_ara.append(predicted)
    print("prec:", precision_score(Y_flat, predicted))
    print("rec:", recall_score(Y_flat, predicted))
    print("f1:", f1_score(Y_flat, predicted))
# Out:
# start 2016-03-12 00:00:00
# prec: 0.9393351723627208
# rec: 0.909526434432658
# f1: 0.924190503947012
# start 2016-04-01 00:00:00
# prec: 0.922310544364475
# rec: 0.890739769737874
# f1: 0.9062502849743296
# start 2016-04-11 00:00:00
# prec: 0.9162696860890895
# rec: 0.9240511434679143
# f1: 0.9201439635494646
# start 2016-04-21 00:00:00
# prec: 0.8917256435262645
# rec: 0.8933121804093449
# f1: 0.8925182069129179
# start 2016-05-01 00:00:00
# prec: 0.8826293955995869
# rec: 0.9039379394721628
# f1: 0.8931565931085482
# start 2016-05-11 00:00:00
# prec: 0.9068396592820777
# rec: 0.9155854923208612
# f1: 0.9111915901397332
