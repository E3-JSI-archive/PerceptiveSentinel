# %% [markdown]
# # Spatio-Temporal Feature extraction task

# %% [markdown]
# Notebook showing a workflow example implementing the spatio-temporal features proposed by Waldner et al. "automated annual cropland mapping using knowledge-based temporal features", 2015 ISPRS Journal of Photogrammetry and Remote Sensing

# %%
from eolearn.core.eoworkflow import EOWorkflow, Dependency
from eolearn.core.eodata import FeatureType

# %%
from sentinelhub import BBox, CRS

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
from eolearn.core import LoadFromDisk, SaveToDisk
from eolearn.io import S2L1CWCSInput, AddSen2CorClassificationFeature
from eolearn.mask import AddCloudMaskTask, get_s2_pixel_cloud_detector, AddValidDataMaskTask
from eolearn.features import AddSpatioTemporalFeaturesTask, AddMaxMinTemporalIndicesTask, AddMaxMinNDVISlopeIndicesTask

# %% [markdown]
# Define ROI BBOX and time interval

# %%
roi_bbox = BBox(bbox=[(4.7104, 52.8991), (4.7983, 52.9521)], crs=CRS.WGS84)
#roi_bbox = BBox(bbox=[(14.546128, 46.156519), (14.584972, 46.128810)], crs=CRS.WGS84)
time_interval = ('2017-01-01', '2017-12-31')

# %% [markdown]
# ### Compute cloud maps from new WMS request

# %% [markdown]
# In this workflow example, the cloud maps are computed from a new WMS request, as the input eopatch does not have the required data

# %%
class ValidDataPredicate:
    def __call__(self, eopatch):
        return np.logical_and(eopatch.mask['IS_DATA'].astype(np.bool), 
                              np.logical_not(eopatch.mask['CLM'].astype(np.bool)))

# %%
LAYER_NAME = 'BANDS-S2-L1C'
FEATURE_NAME = 'BANDS-S2-L1C'

input_task = S2L1CWCSInput(layer=LAYER_NAME, 
                           resx='20m', resy='20m', 
                           maxcc=1, time_difference=datetime.timedelta(hours=2))

add_ndvi = S2L1CWCSInput(layer='NDVI')

cloud_classifier = get_s2_pixel_cloud_detector(all_bands=True)
add_clm = AddCloudMaskTask(cloud_classifier, 
                           'BANDS-S2-L1C', 
                           cm_size_y='60m', 
                           cm_size_x='60m', 
                           cmask_feature='CLM',
                           cprobs_feature='CLP')

add_valmask = AddValidDataMaskTask(predicate=ValidDataPredicate())

add_maxmin_ndvi = AddMaxMinTemporalIndicesTask(mask_data=True)

add_maxmin_red = AddMaxMinTemporalIndicesTask(data_feature=LAYER_NAME, 
                                              data_index=3, 
                                              amax_data_feature='ARGMAX_B4',
                                              amin_data_feature='ARGMIN_B4',
                                              mask_data=True)

add_maxmin_ndvi_sl = AddMaxMinNDVISlopeIndicesTask()

add_stf = AddSpatioTemporalFeaturesTask()

save = SaveToDisk('stf', overwrite=True, compress=True)
# Out:
# Finished loading model, total used 170 iterations

# %% [markdown]
# Run workflow

# %%
workflow = EOWorkflow.make_linear_workflow(input_task, add_ndvi, add_clm, add_valmask, add_maxmin_ndvi, add_maxmin_red, add_maxmin_ndvi_sl, add_stf)

result = workflow.execute({input_task: {'bbox': roi_bbox, 'time_interval': time_interval}})

# %% [markdown]
# Plot results

# %%
eopatch, = [result[key] for key in result.keys()]
eopatch
# Out:
# EOPatch(
#   data: {
#     BANDS-S2-L1C: <class 'numpy.ndarray'>, shape=(53, 295, 295, 13), dtype=float32
#     CLP: <class 'numpy.ndarray'>, shape=(53, 295, 295, 1), dtype=float32
#     NDVI: <class 'numpy.ndarray'>, shape=(53, 295, 295, 1), dtype=float32
#   }
#   mask: {
#     CLM: <class 'numpy.ndarray'>, shape=(53, 295, 295, 1), dtype=uint8
#     IS_DATA: <class 'numpy.ndarray'>, shape=(53, 295, 295, 1), dtype=uint8
#     VALID_DATA: <class 'numpy.ndarray'>, shape=(53, 295, 295, 1), dtype=bool
#   }
#   scalar: {}
#   label: {}
#   vector: {}
#   data_timeless: {
#     ARGMAX_B4: <class 'numpy.ndarray'>, shape=(295, 295, 1), dtype=int64
#     ARGMAX_NDVI: <class 'numpy.ndarray'>, shape=(295, 295, 1), dtype=int64
#     ARGMAX_NDVI_SLOPE: <class 'numpy.ndarray'>, shape=(295, 295, 1), dtype=uint8
#     ARGMIN_B4: <class 'numpy.ndarray'>, shape=(295, 295, 1), dtype=int64
#     ARGMIN_NDVI: <class 'numpy.ndarray'>, shape=(295, 295, 1), dtype=int64
#     ARGMIN_NDVI_SLOPE: <class 'numpy.ndarray'>, shape=(295, 295, 1), dtype=uint8
#     STF: <class 'numpy.ndarray'>, shape=(295, 295, 20), dtype=float32
#   }
#   mask_timeless: {}
#   scalar_timeless: {}
#   label_timeless: {}
#   vector_timeless: {}
#   meta_info: {
#     maxcc: 1
#     service_type: 'wcs'
#     size_x: '20m'
#     size_y: '20m'
#     time_difference: datetime.timedelta(0, 7200)
#     time_interval: <class 'list'>, length=2
#   }
#   bbox: BBox(((4.7104, 52.8991), (4.7983, 52.9521)), crs=EPSG:4326)
#   timestamp: <class 'list'>, length=53
# )

# %%
tidx = 5
plt.figure(figsize=(15, 15))
plt.subplot(131)
plt.imshow(eopatch.mask['IS_DATA'][tidx].squeeze(), vmin=0, vmax=1, cmap='gray')
plt.subplot(132)
plt.imshow(eopatch.mask['CLM'][tidx].squeeze(), vmin=0, vmax=1, cmap='gray')
plt.subplot(133)
plt.imshow(eopatch.mask['VALID_DATA'][tidx].squeeze(), vmin=0, vmax=1, cmap='gray')

# %%
acq_days = [ts.toordinal()-result[add_stf].timestamp[0].toordinal() for ts in result[add_stf].timestamp]

# %%
t, h, w, _ = result[add_stf].mask['CLM'].shape
jcc_2018 = np.array([np.sum(x)/(h*w) for x in result[add_stf].mask['CLM']])
plt.figure(figsize=(15,5))
plt.plot(acq_days, jcc_2018, '*--')
plt.ylabel('Cloud coverage')
plt.xlabel('Days')
plt.title('Cloud coverage over Jable area in 2018')
#plt.xticks(acq_days[::2], eopatch.timestamp[::2], rotation=-30);
plt.imsave
print(sum(np.array(jcc_2018)==1)/len(jcc_2018))
print(np.mean(jcc_2018))
print(sum(jcc_2018 >= 0.7)/len(jcc_2018))
plt.savefig("jablje_clouds_2018.png", bbox_inches="tight")
print(len(jcc_2018)*5)
# Out:
# 0.46551724137931033
# 0.565841170323929
# 0.5172413793103449
# 290

# %%
t, h, w, _ = result[add_stf].mask['CLM'].shape
#jcc_2017 = np.array([np.sum(x)/(h*w) for x in result[add_stf].mask['CLM']])
plt.figure(figsize=(15,5))
plt.plot(acq_days, jcc_2017, '*--')
plt.ylabel('Cloud coverage')
plt.xlabel('Days')
plt.title('Cloud coverage over Jable area in 2017')
#plt.xticks(acq_days[::2], eopatch.timestamp[::2], rotation=-30);
plt.imsave
print(sum(np.array(jcc_2017)==1)/len(jcc_2017))
print(np.mean(jcc_2017))
print(sum(jcc_2017 >= 0.7)/len(jcc_2017))
plt.savefig("jablje_clouds_2017.png", bbox_inches="tight")
print(len(jcc_2017)*5)
# Out:
# 0.45098039215686275
# 0.604935064935065
# 0.5686274509803921
# 255

# %%
t, h, w, _ = result[add_stf].mask['CLM'].shape
cc_2018 = np.array([np.sum(x)/(h*w) for x in result[add_stf].mask['CLM']])
plt.figure(figsize=(15,5))
plt.plot(acq_days, cc_2018, '*--')
plt.ylabel('Cloud coverage')
plt.xlabel('Days')
plt.title('Cloud coverage over Den Helder area in 2018')
#plt.xticks(acq_days[::2], eopatch.timestamp[::2], rotation=-30);
plt.imsave
print(sum(np.array(cc_2018)==1)/len(cc_2018))
print(np.mean(cc_2018))
print(sum(cc_2018 >= 0.3)/len(cc_2018))
plt.savefig("den_helder_clouds_2018.png", bbox_inches="tight")
print(len(cc_2018)*5)
# Out:
# 0.43636363636363634
# 0.7314314068580083
# 0.7818181818181819
# 275

# %%
t, h, w, _ = result[add_stf].mask['CLM'].shape
cc_2016 = np.array([np.sum(x)/(h*w) for x in result[add_stf].mask['CLM']])
plt.figure(figsize=(15,5))
plt.plot(acq_days, cc_2016, '*--')
plt.ylabel('Cloud coverage')
plt.xlabel('Days')
plt.title('Cloud coverage over Den Helder area in 2016')
#plt.xticks(acq_days[::2], eopatch.timestamp[::2], rotation=-30);
plt.imsave
print(sum(np.array(cc_2016)==1)/len(cc_2016))
print(np.mean(cc_2016))
print(sum(cc_2016 >= 0.3)/len(cc_2016))
plt.savefig("den_helder_clouds_2016.png", bbox_inches="tight")
print(len(cc_2016))
# Out:
# 0.34375
# 0.6545188164320598
# 0.6875
# 32

# %%
t, h, w, _ = result[add_stf].mask['CLM'].shape
cc_2017 = np.array([np.sum(x)/(h*w) for x in result[add_stf].mask['CLM']])
plt.figure(figsize=(15,5))
plt.plot(acq_days, cc, '*--')
plt.ylabel('Cloud coverage')
plt.xlabel('Days')
plt.title('Cloud coverage over Den Helder area in 2017')
#plt.xticks(acq_days[::2], eopatch.timestamp[::2], rotation=-30);
plt.imsave
print(sum(np.array(cc)==1)/len(cc))
print(np.mean(cc))
print(sum(cc >= 0.3)/len(cc))
plt.savefig("den_helder_clouds_2017.png", bbox_inches="tight")
# Out:
# 0.4528301886792453
# 0.7563276655482865
# 0.8490566037735849

# %% [markdown]
# Display some of the spatio-temporal features

# %%
print(result[add_stf].data_timeless['STF'].shape)
# Out:
# (295, 295, 20)

# %%
ndvi_patch = eopatch.data['NDVI'][:,227:241,314:330]
plt.figure(figsize=(15,15))
plt.subplot(121)
plt.imshow(ndvi_patch[11].squeeze())
plt.subplot(122)
#plt.plot(eopatch.timestamp, np.mean(ndvi_patch.squeeze(), axis=(1,2)),color='g')
#plt.fill_between(eopatch.timestamp, 
#                 np.mean(ndvi_patch.squeeze(), axis=(1,2))+np.std(ndvi_patch.squeeze(), axis=(1,2)),
#                 np.mean(ndvi_patch.squeeze(), axis=(1,2))-np.std(ndvi_patch.squeeze(), axis=(1,2)),alpha=0.2,color='g')
# Out:
# /Users/joosko/work/ijs/ml/Perceptive_Sentinel/eo-learn/venv/lib/python3.6/site-packages/matplotlib/axes/_base.py:3124: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=-0.5, right=-0.5
#   'left=%s, right=%s') % (left, right))

# %%
eopatch.data["NDVI"]
# Out:
# array([[[[-0.04060356],
#          [-0.03909231],
#          [-0.04197692],
#          ...,
#          [-0.00692135],
#          [-0.00445354],
#          [-0.00819992]],
#
#         [[-0.04101955],
#          [-0.03575879],
#          [-0.03997585],
#          ...,
#          [-0.00500588],
#          [-0.00487104],
#          [-0.01065926]],
#
#         [[-0.0398729 ],
#          [-0.03639708],
#          [-0.03520495],
#          ...,
#          [ 0.02005871],
#          [ 0.00056647],
#          [-0.00259793]],
#
#         ...,
#
#         [[-0.03152872],
#          [-0.03694569],
#          [-0.02176396],
#          ...,
#          [ 0.01735293],
#          [ 0.02619   ],
#          [ 0.03352451]],
#
#         [[-0.03948446],
#          [-0.04148483],
#          [-0.02291802],
#          ...,
#          [ 0.03147581],
#          [ 0.04213663],
#          [ 0.04217143]],
#
#         [[-0.04106187],
#          [-0.0350264 ],
#          [-0.02220091],
#          ...,
#          [ 0.02063965],
#          [ 0.00806115],
#          [ 0.01519602]]],
#
#
#        [[[-0.02256122],
#          [-0.01660449],
#          [-0.01394702],
#          ...,
#          [-0.00568456],
#          [-0.00569296],
#          [-0.0060124 ]],
#
#         [[-0.01638613],
#          [-0.0115343 ],
#          [ 0.00311098],
#          ...,
#          [-0.00441517],
#          [-0.00464134],
#          [-0.0054672 ]],
#
#         [[-0.00248171],
#          [ 0.00543899],
#          [ 0.01407534],
#          ...,
#          [ 0.01954532],
#          [ 0.00035306],
#          [ 0.00104706]],
#
#         ...,
#
#         [[-0.03329498],
#          [-0.02186461],
#          [-0.00604145],
#          ...,
#          [ 0.01493984],
#          [ 0.02423388],
#          [ 0.0340915 ]],
#
#         [[-0.03383802],
#          [-0.02887837],
#          [-0.00560704],
#          ...,
#          [ 0.02655678],
#          [ 0.05146096],
#          [ 0.0417104 ]],
#
#         [[-0.03521498],
#          [-0.03014699],
#          [-0.00781987],
#          ...,
#          [ 0.01419985],
#          [ 0.00815705],
#          [ 0.02780556]]],
#
#
#        [[[ 0.00976126],
#          [ 0.02093359],
#          [ 0.01694697],
#          ...,
#          [ 0.0227917 ],
#          [ 0.02317194],
#          [ 0.0277355 ]],
#
#         [[ 0.00434667],
#          [-0.00649057],
#          [ 0.00560922],
#          ...,
#          [ 0.01816716],
#          [ 0.00425317],
#          [ 0.02283875]],
#
#         [[ 0.00044809],
#          [ 0.00521958],
#          [-0.00814504],
#          ...,
#          [ 0.01432537],
#          [-0.00196625],
#          [-0.00622122]],
#
#         ...,
#
#         [[ 0.00978305],
#          [ 0.0115487 ],
#          [-0.0054444 ],
#          ...,
#          [ 0.02139949],
#          [ 0.0083658 ],
#          [ 0.01732579]],
#
#         [[ 0.00987414],
#          [ 0.00408634],
#          [ 0.00164253],
#          ...,
#          [ 0.00049425],
#          [ 0.00233651],
#          [ 0.00487069]],
#
#         [[-0.00644854],
#          [ 0.00608495],
#          [-0.00354105],
#          ...,
#          [-0.00686588],
#          [-0.00091139],
#          [-0.00766329]]],
#
#
#        ...,
#
#
#        [[[-0.04778913],
#          [-0.04845632],
#          [-0.04676837],
#          ...,
#          [-0.00387018],
#          [-0.0101982 ],
#          [-0.00372313]],
#
#         [[-0.04674558],
#          [-0.05184536],
#          [-0.0473    ],
#          ...,
#          [-0.00794743],
#          [-0.00652203],
#          [-0.00984114]],
#
#         [[-0.04475114],
#          [-0.05003283],
#          [-0.04643206],
#          ...,
#          [ 0.00583213],
#          [-0.0065371 ],
#          [-0.00601577]],
#
#         ...,
#
#         [[-0.02270026],
#          [-0.00290211],
#          [ 0.00036661],
#          ...,
#          [ 0.02228572],
#          [ 0.03873245],
#          [ 0.02861345]],
#
#         [[-0.02924118],
#          [-0.01420502],
#          [ 0.00264243],
#          ...,
#          [ 0.02722925],
#          [ 0.03552315],
#          [ 0.04132706]],
#
#         [[-0.03778208],
#          [-0.03571484],
#          [-0.02211472],
#          ...,
#          [ 0.01623815],
#          [ 0.01319484],
#          [ 0.01291735]]],
#
#
#        [[[-0.00896922],
#          [-0.01180476],
#          [-0.01409596],
#          ...,
#          [ 0.00312938],
#          [ 0.00381872],
#          [ 0.00080643]],
#
#         [[-0.01102501],
#          [-0.01117793],
#          [-0.00931115],
#          ...,
#          [ 0.00421135],
#          [ 0.00303732],
#          [ 0.00442195]],
#
#         [[-0.01166593],
#          [-0.0119271 ],
#          [-0.00906667],
#          ...,
#          [ 0.016225  ],
#          [ 0.00850682],
#          [ 0.0104026 ]],
#
#         ...,
#
#         [[-0.01482004],
#          [-0.01158605],
#          [-0.01091145],
#          ...,
#          [ 0.0162264 ],
#          [ 0.01789495],
#          [ 0.01654969]],
#
#         [[-0.01212885],
#          [-0.0149153 ],
#          [-0.01011543],
#          ...,
#          [ 0.01510821],
#          [ 0.01703557],
#          [ 0.01946476]],
#
#         [[-0.01095819],
#          [-0.01204284],
#          [-0.01209219],
#          ...,
#          [ 0.00946011],
#          [ 0.01432874],
#          [ 0.01640121]]],
#
#
#        [[[ 0.00589121],
#          [ 0.00520441],
#          [ 0.01125238],
#          ...,
#          [ 0.00654801],
#          [ 0.00598585],
#          [ 0.01424808]],
#
#         [[ 0.00625942],
#          [ 0.00693005],
#          [ 0.01477992],
#          ...,
#          [ 0.00876154],
#          [ 0.00986183],
#          [ 0.01562979]],
#
#         [[ 0.01202941],
#          [ 0.01588042],
#          [ 0.01253893],
#          ...,
#          [ 0.01404681],
#          [ 0.01532379],
#          [ 0.00998931]],
#
#         ...,
#
#         [[ 0.01372112],
#          [ 0.0092619 ],
#          [ 0.00876993],
#          ...,
#          [ 0.0206673 ],
#          [ 0.01940248],
#          [ 0.01645874]],
#
#         [[ 0.0100723 ],
#          [ 0.01309468],
#          [ 0.01228041],
#          ...,
#          [ 0.01727244],
#          [ 0.02334873],
#          [ 0.02917192]],
#
#         [[ 0.00645337],
#          [ 0.01095955],
#          [ 0.01531945],
#          ...,
#          [ 0.02199557],
#          [ 0.03239116],
#          [ 0.03198095]]]], dtype=float32)

# %%
plt.figure(figsize=(15,15))
plt.tight_layout()
plt.subplot(321)
plt.imshow(eopatch.data_timeless['ARGMAX_NDVI'].squeeze())
plt.title("Temporal indices for argmax NDVI - no interpolation")
plt.colorbar()
plt.subplot(322)
plt.imshow(eopatch.data_timeless['ARGMIN_NDVI'].squeeze())
plt.title("Temporal indices for argmin NDVI - no interpolation")
plt.colorbar()
plt.subplot(323)
plt.imshow(eopatch.data_timeless['ARGMAX_NDVI_SLOPE'].squeeze())
plt.title("Temporal indices for argmax NDVI slope")
plt.colorbar()
plt.subplot(324)
plt.imshow(eopatch.data_timeless['ARGMIN_NDVI_SLOPE'].squeeze())
plt.title("Temporal indices for argmin NDVI slope")
plt.colorbar()
plt.subplot(325)
plt.imshow(eopatch.data_timeless['ARGMAX_B4'].squeeze())
plt.title("Temporal indices for argmax red")
plt.colorbar()

# %%
plt.figure(figsize=(15,15))
plt.subplot(321)
plt.imshow(eopatch.data_timeless['STF'][:,:,[2,1,0]])
plt.title("IR-R-G reflectances for argmax NDVI")
plt.subplot(322)
plt.imshow(eopatch.data_timeless['STF'][:,:,[6,5,4]])
plt.title("IR-R-G reflectances for argmin NDVI")
plt.subplot(323)
plt.imshow(eopatch.data_timeless['STF'][:,:,[10,9,8]])
plt.title("IR-R-G reflectances for argmax NDVI slope")
plt.subplot(324)
plt.imshow(eopatch.data_timeless['STF'][:,:,[14,13,12]])
plt.title("IR-R-G reflectances for argmin NDVI slope")
plt.subplot(325)
plt.imshow(eopatch.data_timeless['STF'][:,:,[18,17,16]])
plt.title("IR-R-G reflectances for argmax red")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(0.5,1,'IR-R-G reflectances for argmax red')

# %%
eopatch.remove_feature(FeatureType.DATA_TIMELESS, 'ARGMAX_NDVI')
eopatch.remove_feature(FeatureType.DATA_TIMELESS, 'ARGMIN_NDVI')
eopatch.remove_feature(FeatureType.DATA_TIMELESS, 'ARGMAX_NDVI_SLOPE')
eopatch.remove_feature(FeatureType.DATA_TIMELESS, 'ARGMIN_NDVI_SLOPE')
eopatch.remove_feature(FeatureType.DATA_TIMELESS, 'ARGMAX_B4')
eopatch.remove_feature(FeatureType.DATA_TIMELESS, 'ARGMIN_B4')
eopatch.remove_feature(FeatureType.DATA_TIMELESS, 'STF')
eopatch.remove_feature(FeatureType.DATA, 'CLP')
eopatch.remove_feature(FeatureType.MASK, 'CLM')

# %%
save(eopatch, eopatch_folder='eopatch')
# Out:
# WARNING:eolearn.core.eodata:Overwriting data in stf/eopatch
# EOPatch(
#   data: {
#     BANDS-S2-L1C: <class 'numpy.ndarray'>, shape=(66, 278, 506, 13), dtype=float32
#     NDVI: <class 'numpy.ndarray'>, shape=(66, 278, 506, 1), dtype=float32
#   }
#   mask: {
#     IS_DATA: <class 'numpy.ndarray'>, shape=(66, 278, 506, 1), dtype=uint8
#     VALID_DATA: <class 'numpy.ndarray'>, shape=(66, 278, 506, 1), dtype=bool
#   }
#   scalar: {}
#   label: {}
#   vector: {}
#   data_timeless: {}
#   mask_timeless: {}
#   scalar_timeless: {}
#   label_timeless: {}
#   vector_timeless: {}
#   meta_info: {
#     maxcc: 1
#     service_type: 'wcs'
#     size_x: '20m'
#     size_y: '20m'
#     time_difference: datetime.timedelta(0, 7200)
#     time_interval: <class 'tuple'>, length=2
#   }
#   bbox: BBox(((5.6, 52.63), (5.75, 52.68)), crs=EPSG:4326)
#   timestamp: <class 'list'>, length=66
# )

# %% [markdown]
# ### Repeat using interpolation to NDVI and bands

# %%
from eolearn.features import SplineInterpolation

# %%
load = LoadFromDisk('stf')

interp_ndvi = SplineInterpolation((FeatureType.DATA, 'NDVI'), mask_feature=(FeatureType.MASK, 'VALID_DATA'), spline_degree=3, smoothing_factor=0.1)

interp_bands = SplineInterpolation((FeatureType.DATA, 'NDVI'), mask_feature=(FeatureType.MASK, 'VALID_DATA'), spline_degree=3, smoothing_factor=0.1)

add_maxmin_ndvi = AddMaxMinTemporalIndicesTask(mask_data=False)

add_maxmin_red = AddMaxMinTemporalIndicesTask(data_feature=LAYER_NAME, 
                                              data_index=3, 
                                              amax_data_feature='ARGMAX_B4',
                                              amin_data_feature='ARGMIN_B4',
                                              mask_data=False)

add_maxmin_ndvi_sl = AddMaxMinNDVISlopeIndicesTask()

add_stf = AddSpatioTemporalFeaturesTask()

# %%
workflow_with_interp = EOWorkflow.make_linear_workflow( load, interp_ndvi, interp_bands, add_maxmin_ndvi, add_maxmin_red, add_maxmin_ndvi_sl, add_stf )

result_with_interp = workflow_with_interp.execute({load:{'eopatch_folder':'eopatch'}})

# %%
eopatch_wi, = [result_with_interp[key] for key in result_with_interp.keys()]
eopatch_wi.features

# %%
ndvi_patch = eopatch_wi.data['NDVI'][:,227:241,314:330]
plt.figure(figsize=(15,15))
plt.subplot(121)
plt.imshow(ndvi_patch[11].squeeze())
plt.subplot(122)
plt.plot(eopatch_wi.timestamp, np.mean(ndvi_patch.squeeze(), axis=(1,2)),color='g')
plt.fill_between(eopatch_wi.timestamp, 
                 np.mean(ndvi_patch.squeeze(), axis=(1,2))+np.std(ndvi_patch.squeeze(), axis=(1,2)),
                 np.mean(ndvi_patch.squeeze(), axis=(1,2))-np.std(ndvi_patch.squeeze(), axis=(1,2)),alpha=0.2,color='g')

# %%
plt.figure(figsize=(15,15))
plt.tight_layout()
plt.subplot(321)
plt.imshow(eopatch_wi.data_timeless['ARGMAX_NDVI'].squeeze())
plt.title("Temporal indices for argmax NDVI - no interpolation")
plt.colorbar()
plt.subplot(322)
plt.imshow(eopatch_wi.data_timeless['ARGMIN_NDVI'].squeeze())
plt.title("Temporal indices for argmin NDVI - no interpolation")
plt.colorbar()
plt.subplot(323)
plt.imshow(eopatch_wi.data_timeless['ARGMAX_NDVI_SLOPE'].squeeze())
plt.title("Temporal indices for argmax NDVI slope")
plt.colorbar()
plt.subplot(324)
plt.imshow(eopatch_wi.data_timeless['ARGMIN_NDVI_SLOPE'].squeeze())
plt.title("Temporal indices for argmin NDVI slope")
plt.colorbar()
plt.subplot(325)
plt.imshow(eopatch_wi.data_timeless['ARGMAX_B4'].squeeze())
plt.title("Temporal indices for argmax red")
plt.colorbar()

# %%
plt.figure(figsize=(15,15))
plt.subplot(321)
plt.imshow(eopatch_wi.data_timeless['STF'][:,:,[2,1,0]])
plt.title("IR-R-G reflectances for argmax NDVI")
plt.subplot(322)
plt.imshow(eopatch_wi.data_timeless['STF'][:,:,[6,5,4]])
plt.title("IR-R-G reflectances for argmin NDVI")
plt.subplot(323)
plt.imshow(eopatch_wi.data_timeless['STF'][:,:,[10,9,8]])
plt.title("IR-R-G reflectances for argmax NDVI slope")
plt.subplot(324)
plt.imshow(eopatch_wi.data_timeless['STF'][:,:,[14,13,12]])
plt.title("IR-R-G reflectances for argmin NDVI slope")
plt.subplot(325)
plt.imshow(eopatch_wi.data_timeless['STF'][:,:,[18,17,16]])
plt.title("IR-R-G reflectances for argmax red")

# %%
del eopatch_wi
